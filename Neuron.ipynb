# %%
import torch
import torch.nn as nn

# %%
# Input
torch.manual_seed(42) #same output
inputs = torch.tensor([1.0, 2.0, 3.0])

# %%
neuron = nn.Linear(in_features = 3, out_features=1)

# %%
output = neuron(inputs)

# %%
output
# Out:
# tensor([1.5244], grad_fn=<ViewBackward0>)

# %%
# verify ... formula
neuron.weight @ input + neuron.bias
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # verify ... formula
# ----> 2 neuron.weight @ input + neuron.bias
#
# TypeError: unsupported operand type(s) for @: 'Parameter' and 'method'

# %% [raw]
# neuron.weight

# %% [raw]
# neuron.bias
